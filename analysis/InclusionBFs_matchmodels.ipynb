# %%
setwd("C:/Users/cb383/Desktop/YearFour/controllearning/LWPCtufb/data/csvdata")

library(methods)
library(BayesFactor)
library(bayestestR)
# Out:
# Loading required package: coda
# Warning message:
# "package 'coda' was built under R version 3.5.2"Loading required package: Matrix
# ************
# Welcome to BayesFactor 0.9.12-4.2. If you have questions, please contact Richard Morey (richarddmorey@gmail.com).
#
# Type BFManual() to open the manual.
# ************

# %%
rawRTData <- read.csv('SC_ANOVA_RT.csv')
rawRTData <- within(rawRTData, {subject <- factor(subject)
    BlockType <- factor(BlockType)
    Congruency <- factor(Congruency)
    BlockOrder <- factor(BlockOrder)
})
SC_RT_runANOVA <- anovaBF(RT ~ BlockType*Congruency*BlockOrder + subject, data=rawRTData, whichRandom="subject")
print(bayesfactor_inclusion(SC_RT_runANOVA, match_models=TRUE))

#

rawRTData_T <- read.csv('SCT_ANOVA_RT.csv')
rawRTData_T <- within(rawRTData_T, {subject <- factor(subject)
    BlockType <- factor(BlockType)
    Congruency <- factor(Congruency)
    BlockOrder <- factor(BlockOrder)
})
SCT_RT_runANOVA <- anovaBF(RT ~ BlockType*Congruency*BlockOrder + subject, data=rawRTData_T, whichRandom="subject")
print(bayesfactor_inclusion(SCT_RT_runANOVA, match_models=TRUE))

#

rawACCData <- read.csv('SC_ANOVA_ACC.csv')
rawACCData <- within(rawACCData, {subject <- factor(subject)
    BlockType <- factor(BlockType)
    Congruency <- factor(Congruency)
    BlockOrder <- factor(BlockOrder)
})
SC_ACC_runANOVA <- anovaBF(Accuracy ~ BlockType*Congruency*BlockOrder + subject, data=rawACCData, whichRandom="subject")
print(bayesfactor_inclusion(SC_ACC_runANOVA, match_models=TRUE))

#

rawACCData_T <- read.csv('SCT_ANOVA_ACC.csv')
rawACCData_T <- within(rawACCData_T, {subject <- factor(subject)
    BlockType <- factor(BlockType)
    Congruency <- factor(Congruency)
    BlockOrder <- factor(BlockOrder)
})
SCT_ACC_runANOVA <- anovaBF(Accuracy ~ BlockType*Congruency*BlockOrder + subject, data=rawACCData_T, whichRandom="subject")
print(bayesfactor_inclusion(SCT_ACC_runANOVA, match_models=TRUE))
# Out:
# # Inclusion Bayes Factors (Model Averaged)
#
#                                 Pr(prior) Pr(posterior) Inclusion BF
# subject                             1.000       1.0e+00          NaN
# BlockType                           0.263       3.7e-41     8.34e+08
# Congruency                          0.263       4.8e-30     3.82e+65
# BlockType:Congruency                0.263       7.9e-01     1.09e+29
# BlockOrder                          0.263       6.0e-16         0.39
# BlockOrder:BlockType                0.263       7.9e-01     7.46e+14
# BlockOrder:Congruency               0.263       3.7e-01         0.88
# BlockOrder:BlockType:Congruency     0.053       2.1e-01         0.55
#
# * Compared among: matched models only
# *    Priors odds: uniform-equal
# # Inclusion Bayes Factors (Model Averaged)
#
#                                 Pr(prior) Pr(posterior) Inclusion BF
# subject                             1.000       1.0e+00          NaN
# BlockType                           0.263       4.1e-08         55.8
# Congruency                          0.263       2.0e-02     1.63e+99
# BlockType:Congruency                0.263       9.0e-02         1.64
# BlockOrder                          0.263       1.4e-08         0.22
# BlockOrder:BlockType                0.263       1.4e-01     4.87e+06
# BlockOrder:Congruency               0.263       8.4e-02          1.4
# BlockOrder:BlockType:Congruency     0.053       8.6e-01        17.14
#
# * Compared among: matched models only
# *    Priors odds: uniform-equal
# # Inclusion Bayes Factors (Model Averaged)
#
#                                 Pr(prior) Pr(posterior) Inclusion BF
# subject                             1.000       1.0e+00          NaN
# BlockType                           0.263       6.3e-38     1.66e+08
# Congruency                          0.263       3.0e-31     6.84e+35
# BlockType:Congruency                0.263       4.8e-02     1.17e+29
# BlockOrder                          0.263       3.7e-11         0.99
# BlockOrder:BlockType                0.263       4.8e-02     8.84e+08
# BlockOrder:Congruency               0.263       1.6e-02         0.52
# BlockOrder:BlockType:Congruency     0.053       9.5e-01        57.74
#
# * Compared among: matched models only
# *    Priors odds: uniform-equal
# # Inclusion Bayes Factors (Model Averaged)
#
#                                 Pr(prior) Pr(posterior) Inclusion BF
# subject                             1.000       1.0e+00          NaN
# BlockType                           0.263       2.1e-20         0.24
# Congruency                          0.263       1.3e-06     1.99e+35
# BlockType:Congruency                0.263       1.7e-05         1.24
# BlockOrder                          0.263       1.4e-20         0.35
# BlockOrder:BlockType                0.263       3.1e-05     9.98e+14
# BlockOrder:Congruency               0.263       2.7e-05         8.61
# BlockOrder:BlockType:Congruency     0.053       1.0e+00     6.64e+04
#
# * Compared among: matched models only
# *    Priors odds: uniform-equal

# %%
rawRTData_E <- read.csv('SC_ANOVA_RT_early.csv')
rawRTData_E <- within(rawRTData_E, {subject <- factor(subject)
    Congruency <- factor(Congruency)
    BlockOrder <- factor(BlockOrder)
})
SC_RT_runANOVA_E <- anovaBF(RT ~ Congruency*BlockOrder + subject, data=rawRTData_E, whichRandom="subject")
print(bayesfactor_inclusion(SC_RT_runANOVA_E, match_models=TRUE))

#

rawRTData_T_E <- read.csv('SCT_ANOVA_RT_early.csv')
rawRTData_T_E <- within(rawRTData_T_E, {subject <- factor(subject)
    Congruency <- factor(Congruency)
    BlockOrder <- factor(BlockOrder)
})
SCT_RT_runANOVA_E <- anovaBF(RT ~ Congruency*BlockOrder + subject, data=rawRTData_T_E, whichRandom="subject")
print(bayesfactor_inclusion(SCT_RT_runANOVA_E, match_models=TRUE))

#

rawACCData_E <- read.csv('SC_ANOVA_ACC_early.csv')
rawACCData_E <- within(rawACCData_E, {subject <- factor(subject)
    Congruency <- factor(Congruency)
    BlockOrder <- factor(BlockOrder)
})
SC_ACC_runANOVA_E <- anovaBF(Accuracy ~ Congruency*BlockOrder + subject, data=rawACCData_E, whichRandom="subject")
print(bayesfactor_inclusion(SC_ACC_runANOVA_E, match_models=TRUE))

#

rawACCData_T_E <- read.csv('SCT_ANOVA_ACC_early.csv')
rawACCData_T_E <- within(rawACCData_T_E, {subject <- factor(subject)
    Congruency <- factor(Congruency)
    BlockOrder <- factor(BlockOrder)
})
SCT_ACC_runANOVA_E <- anovaBF(Accuracy ~ Congruency*BlockOrder + subject, data=rawACCData_T_E, whichRandom="subject")
print(bayesfactor_inclusion(SCT_ACC_runANOVA_E, match_models=TRUE))
# Out:
# # Inclusion Bayes Factors (Model Averaged)
#
#                       Pr(prior) Pr(posterior) Inclusion BF
# subject                     1.0       1.0e+00          NaN
# Congruency                  0.4       3.8e-17     2.74e+27
# BlockOrder                  0.4       1.9e-17         0.95
# BlockOrder:Congruency       0.2       1.0e+00     5.40e+16
#
# * Compared among: matched models only
# *    Priors odds: uniform-equal
# # Inclusion Bayes Factors (Model Averaged)
#
#                       Pr(prior) Pr(posterior) Inclusion BF
# subject                     1.0         1.000          NaN
# Congruency                  0.4         0.119     3.55e+47
# BlockOrder                  0.4         0.035         0.42
# BlockOrder:Congruency       0.2         0.881        25.08
#
# * Compared among: matched models only
# *    Priors odds: uniform-equal
# # Inclusion Bayes Factors (Model Averaged)
#
#                       Pr(prior) Pr(posterior) Inclusion BF
# subject                     1.0       1.0e+00          NaN
# Congruency                  0.4       6.3e-17     7.84e+20
# BlockOrder                  0.4       6.3e-17     1.17e+05
# BlockOrder:Congruency       0.2       1.0e+00     1.59e+16
#
# * Compared among: matched models only
# *    Priors odds: uniform-equal
# # Inclusion Bayes Factors (Model Averaged)
#
#                       Pr(prior) Pr(posterior) Inclusion BF
# subject                     1.0         1.000          NaN
# Congruency                  0.4         0.039     4.50e+23
# BlockOrder                  0.4         0.019         0.91
# BlockOrder:Congruency       0.2         0.961        51.51
#
# * Compared among: matched models only
# *    Priors odds: uniform-equal

# %%
rawHitdata <- read.csv('Hit_AnovaComb.csv')
rawHitdata <- within(rawHitdata, {subject <- factor(subject)
    BlockType <- factor(BlockType)
    BlockOrder <- factor(BlockOrder)
    Congruency <- factor(Congruency)
})
Hit_runANOVA <- anovaBF(Hit ~ BlockType*Congruency*BlockOrder + subject, data=rawHitdata, whichRandom="subject")
print(bayesfactor_inclusion(Hit_runANOVA, match_models=TRUE))
# Out:
# # Inclusion Bayes Factors (Model Averaged)
#
#                                 Pr(prior) Pr(posterior) Inclusion BF
# subject                             1.000       1.0e+00          NaN
# BlockType                           0.263       3.3e-07         0.08
# Congruency                          0.263       1.1e-01         0.13
# BlockType:Congruency                0.263       1.4e-02         0.11
# BlockOrder                          0.263       1.0e-06          0.3
# BlockOrder:BlockType                0.263       1.0e+00     1.32e+07
# BlockOrder:Congruency               0.263       1.6e-02         0.13
# BlockOrder:BlockType:Congruency     0.053       8.1e-04         0.53
#
# * Compared among: matched models only
# *    Priors odds: uniform-equal

# %%
rawHitdata_r1 <- read.csv('Hit_Anova_r1Comb.csv')
rawHitdata_r1 <- within(rawHitdata_r1, {subject <- factor(subject)
    BlockOrder <- factor(BlockOrder)
    Congruency <- factor(Congruency)
})
Hit_runANOVA_E <- anovaBF(Hit ~ Congruency*BlockOrder + subject, data=rawHitdata_r1, whichRandom="subject")
print(bayesfactor_inclusion(Hit_runANOVA_E, match_models=TRUE))
# Out:
# # Inclusion Bayes Factors (Model Averaged)
#
#                       Pr(prior) Pr(posterior) Inclusion BF
# subject                     1.0         1.000          NaN
# Congruency                  0.4         0.864         9.81
# BlockOrder                  0.4         0.302         0.47
# BlockOrder:Congruency       0.2         0.048         0.18
#
# * Compared among: matched models only
# *    Priors odds: uniform-equal

# %%
rawHitdata_CH <- read.csv('Hit_Anova_CHComb.csv')
rawHitdata_CH <- within(rawHitdata_CH, {subject <- factor(subject)
    BlockOrder <- factor(BlockOrder)
    Congruency <- factor(Congruency)
    ContextHalf <- factor(ContextHalf)
})
Hit_runANOVA_CH <- anovaBF(Hit ~ Congruency*BlockOrder*ContextHalf + subject, data=rawHitdata_CH, whichRandom="subject")
print(bayesfactor_inclusion(Hit_runANOVA_CH, match_models=TRUE))
# Out:
# # Inclusion Bayes Factors (Model Averaged)
#
#                                   Pr(prior) Pr(posterior) Inclusion BF
# subject                               1.000        1.0000          NaN
# ContextHalf                           0.263        0.6714     9.13e+09
# Congruency                            0.263        0.0071         0.17
# Congruency:ContextHalf                0.263        0.1105         0.15
# BlockOrder                            0.263        0.0155         0.49
# BlockOrder:ContextHalf                0.263        0.1364         0.19
# BlockOrder:Congruency                 0.263        0.8494       268.02
# BlockOrder:Congruency:ContextHalf     0.053        0.1009         5.28
#
# * Compared among: matched models only
# *    Priors odds: uniform-equal
